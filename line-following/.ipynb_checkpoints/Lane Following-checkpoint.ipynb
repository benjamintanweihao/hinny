# %%
# %matplotlib inline
import os
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
files = [os.path.join('data', f) for f in os.listdir('data') if f.endswith('.jpg')]

# %%
image = cv2.imread(files[0])
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image)
plt.show()

# %%
# apply gaussian blur
kernel_size = (15, 15)
gauss_image = cv2.GaussianBlur(image, kernel_size, 0)

plt.imshow(gauss_image)
plt.show()

# %%
# color transformation to HSV
hsv_image = cv2.cvtColor(gauss_image, cv2.COLOR_RGB2HSV)
plt.imshow(hsv_image)
plt.show()

# %%
lower_black = np.array([36, 0, 0])
upper_black = np.array([36, 255, 255])

thresh = cv2.inRange(hsv_image, lower_black, upper_black)
plt.imshow(thresh_1)
plt.show()

# %%
# dilation to join pixels that are close by
rect_kernel = (5, 3)
thresh = cv2.dilate(thresh_1, rect_kernel, iterations=1)
plt.imshow(thresh)
plt.show()

# %%
# canny edge edge detection
low_threshold = 200
high_threshold = 400
canny_edges = cv2.Canny(thresh, low_threshold, high_threshold)
plt.imshow(canny_edges)
plt.show()

# %%
def roi(edges):
    height, width = edges.shape
    mask = np.zeros_like(edges)
    
    # create mask
    polygon = np.array([[
        (0, height * 0.5),
        (width, height * 0.5),
        (width, height),
        (0, height)
    ]], np.int32)
    
    cv2.fillPoly(mask, polygon, 255)
    cropped = cv2.bitwise_and(edges, mask)
    return cropped

roi_image = roi(canny_edges)
plt.imshow(roi_image)
plt.show()

# %%
def detect_line_segments(cropped):
    rho = 1 # distance precision in pixels
    angle = np.pi / 180 # angular precision in radians
    min_threshold = 10 # min votes
    line_segments = cv2.HoughLinesP(cropped, rho, angle, min_threshold, np.array([]), 
                                    minLineLength=10, maxLineGap=15)
    return line_segments

# %%
line_segments = detect_line_segments(roi_image)
for ls in line_segments:
    print(ls)
# Out:
# [[ 87  62 152 113]]
# [[101  69 152 110]]
# [[ 89  60 135  97]]
# [[ 9 64 31 60]]
# [[85 61 98 71]]
# [[ 8 61 56 61]]
# [[137 100 150 113]]

# %%
def make_points(image, line):
    slope, intercept = line
    y1 = int(image.shape[0]) # bottom of the image
    y2 = int(y1*3/5)         # slightly lower than the middle
    x1 = int((y1 - intercept)/slope)
    x2 = int((y2 - intercept)/slope)
    return [[x1, y1, x2, y2]]


def average_slope_intercept(frame, line_segments):
    lane_lines = []
    if line_segments is None:
        return lane_lines
    
    height, width, _ = frame.shape

    left_fit = []
    right_fit = []
    
    boundary = 1/3
    left_region_boundary = width * (1 - boundary)
    right_region_boundary = width * boundary
    
    for line_segment in line_segments:
        for x1, y1, x2, y2 in line_segment:
            if abs(x1 - x2) < 0.1:
                # skip vertical lines
                continue
            fit = np.polyfit((x1, x2), (y1, y2), 1)
            slope = fit[0]
            intercept = fit[1]
            
            # NOTE: Technically if we are following a single line, we don't have to
            # NOTE: break things up like this, but it will be useful later on.
            if slope < 0:
                # we have agreement
                if x1 < left_region_boundary and x2 < left_region_boundary:
                    left_fit.append((slope, intercept))
            else:
                if x1 > right_region_boundary and x2 < right_region_boundary:
                    right_fit.append((slope, intercept))
            
    left_fit_average = np.average(left_fit, axis=0)
    if len(left_fit) > 0:
        lane_lines.append(make_points(frame, left_fit_average))
    
    right_fit_average = np.average(right_fit, axis=0)
    if len(right_fit) > 0:
        lane_lines.append(make_points(frame, right_fit_average))
        
    print(lane_lines)
    
    return lane_lines

# %%
averaged_lines = average_slope_intercept(image, line_segments)
# Out:
# [[[-298, 120, -34, 72]]]

# %%
def display_lines(image, lines):
    line_image = np.zeros_like(image)
    if lines is not None:
        for line in lines:
            x1, y1, x2, y2 = line.reshape(4)
            cv2.line(line_image, (x1, y1), (x2, y2), (255, 0, 0), 15)
    return line_image

# %%
line_image = display_lines(image, averaged_lines)
plt.imshow(line_image)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-123-fe20609b43f8> in <module>
# ----> 1 line_image = display_lines(image, averaged_lines)
#       2 plt.imshow(line_image)
#       3 plt.show()
#
# <ipython-input-122-6d4138a1b162> in display_lines(image, lines)
#       3     if lines is not None:
#       4         for line in lines:
# ----> 5             x1, y1, x2, y2 = line.reshape(4)
#       6             cv2.line(line_image, (x1, y1), (x2, y2), (255, 0, 0), 15)
#       7     return line_image
#
# AttributeError: 'list' object has no attribute 'reshape'

# %%
combo_image = cv2.addWeighted(image, 0.8, line_image, 1, 1)
plt.imshow(combo_image)
plt.show()
